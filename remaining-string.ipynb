# %%
for _ in range(int(input())):
    s = input()
    c = input()
    i = int(input())
    charfoundflag = 0
    
    if len(s) == 0:
        print("Empty string")
    
    for k in range(len(s)):
        if s[k] == c:
            charfoundflag = 1
            i = i-1
            if i == 0:
                if k == len(s)-1:
                    print("Empty string")
                    break
                print(s[k+1:])
                break
    
    if k == len(s) & i != 0:
        print("Empty string")
    
    if charfoundflag == 0:
        print(s)
# Out:
# 1
# Helloeveryone
# y
# 2
