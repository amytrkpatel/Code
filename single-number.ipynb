# %%
t = int(input())
for _ in range(t):
    n = int(input())
    num = [num for num in input().split()]
    num_dct = {num[i]: 0 for i in range(0, len(num))}
    
    print(num)
    
    flag = 0
    
    for i in num:
        num_dct[i] += 1
    
    print(num_dct)
    
    for key, value in num_dct.items():
        if value % 2 == 1:
            flag = 1
            print(key)
            break
    
            
    if flag == 0:
        print(0)
# Out:
# 1
# 84
# 78 -94 -87 50 -63 -91 -64 41 73 12 68 -83 63 -68 -30 23 70 -94 12 30 -22 -85 -99 16 14 92 57 -63 97 -6 -85 -37 -47 -14 -25 -83 -15 -35 44 88 77 89 4 -55 -33 77 40 27 95 -96 35 68 -98 18 53 2 87 -66 -45 -41 -32 -98 -82 -10 -68 98 -87 -7 -20 29 -33 -4 -71 9 -41 -97 -19 -47 -22 -80 65 42 94 35
# ['78', '-94', '-87', '50', '-63', '-91', '-64', '41', '73', '12', '68', '-83', '63', '-68', '-30', '23', '70', '-94', '12', '30', '-22', '-85', '-99', '16', '14', '92', '57', '-63', '97', '-6', '-85', '-37', '-47', '-14', '-25', '-83', '-15', '-35', '44', '88', '77', '89', '4', '-55', '-33', '77', '40', '27', '95', '-96', '35', '68', '-98', '18', '53', '2', '87', '-66', '-45', '-41', '-32', '-98', '-82', '-10', '-68', '98', '-87', '-7', '-20', '29', '-33', '-4', '-71', '9', '-41', '-97', '-19', '-47', '-22', '-80', '65', '42', '94', '35']
# {'78': 1, '-94': 2, '-87': 2, '50': 1, '-63': 2, '-91': 1, '-64': 1, '41': 1, '73': 1, '12': 2, '68': 2, '-83': 2, '63': 1, '-68': 2, '-30': 1, '23': 1, '70': 1, '30': 1, '-22': 2, '-85': 2, '-99': 1, '16': 1, '14': 1, '92': 1, '57': 1, '97': 1, '-6': 1, '-37': 1, '-47': 2, '-14': 1, '-25': 1, '-15': 1, '-35': 1, '44': 1, '88': 1, '77': 2, '89': 1, '4': 1, '-55': 1, '-33': 2, '40': 1, '27': 1, '95': 1, '-96': 1, '35': 2, '-98': 2, '18': 1, '53': 1, '2': 1, '87': 1, '-66': 1, '-45': 1, '-41': 2, '-32': 1, '-82': 1, '-10': 1, '98': 1, '-7': 1, '-20': 1, '29': 1, '-4': 1, '-71': 1, '9': 1, '-97': 1, '-19': 1, '-80': 1, '65': 1, '42': 1, '94': 1}
# 78
