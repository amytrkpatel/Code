# %%
t = int(input())
for _ in range(t):
	n = int(input())
	x = [int(x) for x in input().split()]
	x.sort()
    
    
	print(x)
# Out:
# 1
# 5
# 0 -8 -10 4 9
# [-10, -8, 0, 4, 9]

# %%
t = int(input())
for _ in range(t):
    n = int(input())
    arr = [int(i) for i in input().split()]
    maxx = max(arr)
    flag = 0
    if maxx <= 0:
        print(1)
    else:
        for i in range(1, maxx+1):
            if i not in arr:
                flag = 1
                print(i)
                break
    if flag == 0:
        print(maxx+1)
# Out:
# 1
# 5
# 1 2 3 4 5
# 6
