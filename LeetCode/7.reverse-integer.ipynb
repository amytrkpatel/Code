# %% [markdown]
# ### 7. Reverse Integer
#
# Problem Link :> https://leetcode.com/problems/reverse-integer/description/
#
# ```python
# Given a signed 32-bit integer x, return x with its digits reversed. If reversing x causes the value to go outside the signed 32-bit integer range [-231, 231 - 1], then return 0.
#
# Assume the environment does not allow you to store 64-bit integers (signed or unsigned).
#
#
# Example 1:
#
# Input: x = 123
# Output: 321
# Example 2:
#
# Input: x = -123
# Output: -321
# Example 3:
#
# Input: x = 120
# Output: 21
#
#
# Constraints:
#
# -231 <= x <= 231 - 1
# ```

# %% [markdown]
# #### Approach1: Using Type Conversion & slicing in python and bit_length() function
#
# #### Complexity analysis
# O(n)
# Use Website: https://www.timecomplexity.ai/

# %%
def reverse(x):
    y = str(x)
    
    #Check if its a negative number
    if x >= 0:
        y = y[::-1]
    else:
        y = "-" + y[:0:-1]
    y = int(y)
    
    #Check bit length of a number
    if y.bit_length() >= 32:
        return 0
    else:
        return y

#Driver code
if __name__=="__main__":
    t = int(input('Enter Number of TestCases'))
    for _ in range(t):
        x = int(input()) # ! Number input
        print(reverse(x))
# Out:
# 32
# 2147483651

# %% [markdown]
# #### Approach 2:
# Using modulo and division operators to separate unit digit and then later multiplyiing it with 10 to get the reverse number.
#
# #### Complexity analysis
# O(log(n)) - The time complexity of the reverse function is O(log(n)) because the while loop iterates through the digits of the input integer x, which has log(n) digits where n is the value of x. Each iteration of the loop involves dividing x by 10, which reduces the size of x by a factor of 10. Therefore, the time complexity is logarithmic in the value of x.
#
# Use Website: https://www.timecomplexity.ai/

# %%
def reverse(x):
    #write your code here
    i = 0
    reversed_x = 0
    is_negative = False
    
    if x < 0:
        is_negative = True
        x = -1 * x
    
    while x:
        print("iteration: ",i)
        unit = x % 10
        print("unit digit: ", unit)
        reversed_x = reversed_x * 10 + unit
        print("reversed digit: ",reversed_x)
        x = x // 10
        print("remaining x: ",x)
        i += 1
    print(reversed_x.bit_length())
    if reversed_x.bit_length() >= 32:
        return 0
    elif is_negative:
        return -1 * reversed_x
    else:
        return reversed_x

#Driver code
if __name__=="__main__":
    t = int(input('Enter Number of TestCases: '))
    for _ in range(t):
        x = int(input()) # ! Number input
        print(reverse(x))
# Out:
# iteration:  0
# unit digit:  3
# reversed digit:  3
# remaining x:  12
# iteration:  1
# unit digit:  2
# reversed digit:  32
# remaining x:  1
# iteration:  2
# unit digit:  1
# reversed digit:  321
# remaining x:  0
# 9
# 321
