# %%
t = int(input())
for _ in range(t):
    n = int(input())
    A = [int(A) for A in input().split()]

    while len(A) > 1:
        i=1
        A.insert(0, A[len(A)-1])
        A.pop(A[len(A)-1])
        print(A)
        
        A.pop(A[len(A)-i])
        i = i+1
        print(A)
        
    print(A[0])
# Out:
# 1
# 6
# 1 2 3 4 5 6
# [6, 1, 2, 3, 4, 5]
# [6, 1, 2, 3, 4]
# [4, 6, 1, 2, 4]
# [4, 6, 1, 2]
# [2, 4, 1, 2]
# [2, 4, 2]
# [2, 2, 2]
# [2, 2]
# [2, 2]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-ce09f38b8e17> in <module>
#      10         print(A)
#      11
# ---> 12         A.pop(A[len(A)-i])
#      13         i = i+1
#      14         print(A)
#
# IndexError: pop index out of range
